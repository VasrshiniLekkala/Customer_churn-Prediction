# %%
import sys, os
sys.path.append(os.path.abspath(".."))

# %%
from src.data_preprocessing import preprocess_data
from src.feature_engineering import feature_engineering
from src.train_model import train_model
from src.evaluate_model import evaluate_model
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 3
#       1 from src.data_preprocessing import preprocess_data
#       2 from src.feature_engineering import feature_engineering
# ----> 3 from src.train_model import train_model
#       4 from src.evaluate_model import evaluate_model
#
# ImportError: cannot import name 'train_model' from 'src.train_model' (c:\Users\Naga Varshini\OneDrive\Desktop\Customer_Churn_Prediction\src\train_model.py)

# %%
import src.feature_engineering as fe
dir(fe)
# Out:
# ['LabelEncoder',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'feature_engineering']
